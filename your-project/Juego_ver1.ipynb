# %%
from juego_v1 import *

juego();
# Out:
# ¿Cuantós jugadores serán? ¿1 o 2?: 1
# Tu pokemon:
# ¡Es un Squirtle!
#
# ¡Ponle un nombre! Fer
#                  Datos
# Nombre             Fer
# Ataque             106
# Defensa            231
# Ataque Especial    182
# Defensa Especial   150
# Velocidad          196
#
#
# ¿Listo para la batalla? y/n y
# Cargando la batalla.........
# ¡Ahora, a pelear!
# Bulbasaur es más rápido. Ataca primero
# |---------------------|
#          100%
#
# ¡Bulbasaur ataca!
#
# ¡Fer ha recibido 37 de daño pero sigue en pie!
# |-----------------   |
#          85%
# |-----------------   |
#          85%
# Elige un ataque: Presiona 1 para mordida. Presiona 2 para pistola de agua 2
#
# ¡Fer ataca!
#
# ¡Bulbasaur ha recibido 51 de daño pero sigue en pie!
# |----------------    |
#          75%
#
#
#
#
# ¿Siguiente ronda? y/n y
# ¡La lucha sigue, siguiente ataque!
# |----------------    |
#          75%
#
# ¡Bulbasaur ataca!
#
# ¡Fer ha recibido 69 de daño pero sigue en pie!
# |-----------         |
# ...
